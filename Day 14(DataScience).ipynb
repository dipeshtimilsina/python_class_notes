# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = ['Nepal','India','China']
y = [12, 45, 3]

plt.bar(x,y,color='green')
plt.show()

# %%
data = np.linspace(0,20,20)

# %%
data
# Out:
# array([ 0.        ,  1.05263158,  2.10526316,  3.15789474,  4.21052632,
#         5.26315789,  6.31578947,  7.36842105,  8.42105263,  9.47368421,
#        10.52631579, 11.57894737, 12.63157895, 13.68421053, 14.73684211,
#        15.78947368, 16.84210526, 17.89473684, 18.94736842, 20.        ])

# %%
x = np.linspace(0,20,100)
y1 = np.sin(x)
y2 = np.cos(x)

plt.plot(x,y1,label = 'Sin')
plt.plot(x,y2, label = 'Cos')
plt.legend(loc=1)
plt.show()

# %%
labels = ['a','b','c']
values = [12,45,10]

# %%
plt.pie(x=values, labels=labels,)
plt.show()

# %%
population = [1234,2313,2342,1231]
countries=['Nepal','China','Bhutan','India']

data = pd.Series(population, index = countries)

# %%
data.index
# Out:
# Index(['Nepal', 'China', 'Bhutan', 'India'], dtype='object')

# %%
data.Nepal
# Out:
# 1234

# %%
population2 = [np.NaN,233,123,432]
countries = ['Nepal','China','Bhutan','India']

data2 = pd.Series(population2 , index = countries)

# %%
data2
# Out:
# Nepal       NaN
# China     233.0
# Bhutan    123.0
# India     432.0
# dtype: float64

# %%
result = data + data2

# %%
result
# Out:
# Nepal        NaN
# China     2546.0
# Bhutan    2465.0
# India     1663.0
# dtype: float64

# %%
result.isna().sum()
# Out:
# 1
